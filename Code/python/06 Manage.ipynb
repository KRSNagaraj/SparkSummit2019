# %% [markdown]
# #Delta Manage and Optimizations
#
# Databricks Delta has nifty optimizations to speed up your queries.

# %%
# %run ./Reference/Setup

# %%
deltaIotPath = userhome + "/delta/iot-pipeline/"
deltaDataPath = userhome + "/delta/customer-data/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## SMALL FILE PROBLEM
#
# Historical and new data is often written in very small files and directories.
#
# This data may be spread across a data center or even across the world (that is, not co-located).
#
# The result is that a query on this data may be very slow due to
# * network latency
# * volume of file metatadata
#
# The solution is to compact many small files into one larger file.
# Databricks Delta has a mechanism for compacting small files.

# %%
display(dbutils.fs.ls(deltaIotPath + "/date=2018-06-01/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00000-28841414-d103-46f3-9f79-dce8405fff7c.c000.snappy.parquet</td><td>part-00000-28841414-d103-46f3-9f79-dce8405fff7c.c000.snappy.parquet</td><td>985</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00001-31266dd3-424b-456f-a5d1-f25918634b44.c000.snappy.parquet</td><td>part-00001-31266dd3-424b-456f-a5d1-f25918634b44.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00001-c39cffad-597d-4f63-a0b9-5265e53bf57c.c000.snappy.parquet</td><td>part-00001-c39cffad-597d-4f63-a0b9-5265e53bf57c.c000.snappy.parquet</td><td>14261</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00002-001574d8-afc7-4d07-80cc-5d281c01218a.c000.snappy.parquet</td><td>part-00002-001574d8-afc7-4d07-80cc-5d281c01218a.c000.snappy.parquet</td><td>953</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00003-44cdba01-9686-4957-9a70-ba42e2740e27.c000.snappy.parquet</td><td>part-00003-44cdba01-9686-4957-9a70-ba42e2740e27.c000.snappy.parquet</td><td>985</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00004-8f3a12fa-fb71-43d7-a824-8da0bf40337b.c000.snappy.parquet</td><td>part-00004-8f3a12fa-fb71-43d7-a824-8da0bf40337b.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00005-bbe2a22e-8c5f-4d53-8a19-c0d39397d13d.c000.snappy.parquet</td><td>part-00005-bbe2a22e-8c5f-4d53-8a19-c0d39397d13d.c000.snappy.parquet</td><td>966</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00006-3afb2563-8147-4585-a293-2bd7854027af.c000.snappy.parquet</td><td>part-00006-3afb2563-8147-4585-a293-2bd7854027af.c000.snappy.parquet</td><td>979</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00007-60c3ff57-2fe0-40cc-a1ec-aa44e553413f.c000.snappy.parquet</td><td>part-00007-60c3ff57-2fe0-40cc-a1ec-aa44e553413f.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00008-3af9b6c0-7ce7-4916-9824-637f8d204c0e.c000.snappy.parquet</td><td>part-00008-3af9b6c0-7ce7-4916-9824-637f8d204c0e.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00009-151e32de-6460-4a56-a9cd-fa85a2580e86.c000.snappy.parquet</td><td>part-00009-151e32de-6460-4a56-a9cd-fa85a2580e86.c000.snappy.parquet</td><td>953</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00010-f3be75f5-e12e-47a1-b302-ecf4aedc7c2d.c000.snappy.parquet</td><td>part-00010-f3be75f5-e12e-47a1-b302-ecf4aedc7c2d.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00011-b289a42c-48e8-4ee6-aa27-663097283dda.c000.snappy.parquet</td><td>part-00011-b289a42c-48e8-4ee6-aa27-663097283dda.c000.snappy.parquet</td><td>985</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00012-e2bbae2d-2873-48c5-a5c8-f5d2d3f50b2c.c000.snappy.parquet</td><td>part-00012-e2bbae2d-2873-48c5-a5c8-f5d2d3f50b2c.c000.snappy.parquet</td><td>966</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00013-1a151a61-bf87-4bbd-9eb9-3d36a9132500.c000.snappy.parquet</td><td>part-00013-1a151a61-bf87-4bbd-9eb9-3d36a9132500.c000.snappy.parquet</td><td>960</td></tr><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline/date=2018-06-01/part-00014-e931bcda-7 ...

# %%
# %sql
SELECT * FROM demo_iot_data_delta where deviceId=379
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>time</th><th>date</th><th>deviceId</th></tr></thead><tbody><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ### Data Skipping and ZORDER
#
# Databricks Delta uses two mechanisms to speed up queries.
#
# <b>Data Skipping</b> is a performance optimization that aims at speeding up queries that contain filters (WHERE clauses).
#
# For example, we have a data set that is partitioned by `date`.
#
# A query using `WHERE date > 2018-06-01` would not access data that resides in partitions that correspond to dates prior to `2018-06-01`.
#
# <b>ZOrdering</b> is a technique to colocate related information in the same set of files.
#
# ZOrdering maps multidimensional data to one dimension while preserving locality of the data points.
#
# Given a column that you want to perform ZORDER on, say `OrderColumn`, Delta
# * takes existing parquet files within a partition
# * maps the rows within the parquet files according to `OrderColumn` using the algorithm described <a href="https://en.wikipedia.org/wiki/Z-order_curve" target="_blank">here</a>
# * (in the case of only one column, the mapping above becomes a linear sort)
# * rewrites the sorted data into new parquet files

# %%
# %sql
OPTIMIZE demo_iot_data_delta
ZORDER by (deviceId)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM demo_iot_data_delta where deviceId=379
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>time</th><th>date</th><th>deviceId</th></tr></thead><tbody><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr><tr><td>Open</td><td>1529091520</td><td>2018-06-01</td><td>379</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ## VACUUM
#
# To save on storage costs you should occasionally clean up invalid files using the `VACUUM` command.
#
# Invalid files are small files compacted into a larger file with the `OPTIMIZE` command.
#
# The  syntax of the `VACUUM` command is
# >`VACUUM name-of-table RETAIN number-of HOURS;`
#
# The `number-of` parameter is the <b>retention interval</b>, specified in hours.
#
# Databricks does not recommend you set a retention interval shorter than seven days because old snapshots and uncommitted files can still be in use by concurrent readers or writers to the table.
#
# The scenario here is:
# 0. User A starts a query off uncompacted files, then
# 0. User B invokes a `VACUUM` command, which deletes the uncompacted files
# 0. User A's query fails because the underlying files have disappeared
#
# Invalid files can also result from updates/upserts/deletions.
#
# More details are provided here: <a href="https://docs.databricks.com/delta/optimizations.html#garbage-collection" target="_blank"> Garbage Collection</a>.

# %%
len(dbutils.fs.ls(deltaIotPath + "/date=2018-06-01"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">26</span><span class="ansired">]: </span>201</div>

# %%
# %sql

VACUUM demo_iot_data_delta RETAIN 0 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/iot-pipeline</td></tr></tbody></table></div>

# %%
len(dbutils.fs.ls(deltaIotPath + "/date=2018-06-01"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">27</span><span class="ansired">]: </span>1</div>

# %% [markdown]
# Count number of files before `VACUUM` for `Country=Sweden`.

# %%
preNumFiles = len(dbutils.fs.ls(deltaDataPath + "/Country=Sweden"))
print (preNumFiles)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2
# </div>

# %%
# %sql
VACUUM customer_data_delta RETAIN 0 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/nagaraj.sengodan@hotmail.com/delta/customer-data</td></tr></tbody></table></div>
