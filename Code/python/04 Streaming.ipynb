# %% [markdown]
# # Databricks Delta Streaming
#
# Data from
# `/mnt/training/definitive-guide/data/activity-data`
# contains smartphone accelerometer samples from all devices and users.
#
# The CSV file consists of the following columns:
#
# - `Index`
# - `Arrival_Time`
# - `Creation_Time`
# - `x`
# - `y`
# - `z`
# - `User`
# - `Model`
# - `Device`
# - `gt`

# %%
# %run "./Reference/Setup"

# %%
dataPath = "/mnt/training/definitive-guide/data/activity-data"
outputPath = userhome + "/gaming"
basePath = userhome + "/advanced-streaming"
checkpointPath = basePath + "/checkpoints"
activityPath = basePath + "/activityCount"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# A streaming system consists of
# * <b>Input source</b> such as Kafka, Azure Event Hub, files on a distributed system or TCP-IP sockets
# * <b>Sinks</b> such as Kafka, Azure Event Hub, various file formats, `forEach` sinks, console sinks or memory sinks

# %% [markdown]
# ### Streaming and Databricks Delta
#
# In streaming, the problems of traditional data pipelines are exacerbated.
#
# Specifically, with frequent meta data refreshes, table repairs and accumulation of small files on a secondly- or minutely-basis!
#
# Many small files result because data (may be) streamed in at low volumes with short triggers.
#
# Databricks Delta is uniquely designed to address these needs.

# %%
static = spark.read.json(dataPath)
dataSchema = static.schema

deltaStreamWithTimestampDF = (spark
  .readStream
  .format("delta")
  .option("maxFilesPerTrigger", 1)
  .schema(dataSchema)
  .json(dataPath)
  .withColumnRenamed('Index', 'User_ID')
  .selectExpr("*","cast(cast(Arrival_Time as double)/1000000000 as timestamp) as event_time")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
deltaStreamingQuery = (deltaStreamWithTimestampDF
  .writeStream
  .format("delta")
  .option("checkpointLocation", checkpointPath)
  .outputMode("append")
  .start(basePath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# See list of active streams.

# %%
for s in spark.streams.active:
  print(s.id)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">c1e80093-4ff4-416a-aa59-998b9c7e4529
# </div>

# %%
activityCountsQuery = (spark.readStream
  .format("delta")
  .load(str(basePath))   
  .groupBy("gt")
  .count()
  .writeStream
  .format("delta")
  .option("checkpointLocation", checkpointPath + "/activityCount")
  .outputMode("complete")
  .start(activityPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import hour, window, col

countsDF = (deltaStreamWithTimestampDF      
  .withWatermark("event_time", "180 minutes")
  .groupBy(window("event_time", "60 minute"),"gt")
  .count()
  .withColumn('hour',hour(col('window.start')))     
)

display(countsDF.withColumn('hour',hour(col('window.start'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>gt</th><th>count</th><th>hour</th></tr></thead><tbody><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>sit</td><td>984714</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>stairsup</td><td>836598</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>stairsdown</td><td>749059</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>null</td><td>835725</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>stand</td><td>910783</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>bike</td><td>863710</td><td>0</td></tr><tr><td>List(1970-01-01T00:00:00.000+0000, 1970-01-01T01:00:00.000+0000)</td><td>walk</td><td>1060402</td><td>0</td></tr></tbody></table></div>

# %%
# ANSWER
for streamingQuery in spark.streams.active:
  streamingQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select count(*) from demo_iot_data_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>110000</td></tr></tbody></table></div>

# %%
print(basePath)
print(activityPath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/nagaraj.sengodan@hotmail.com/advanced-streaming
# dbfs:/user/nagaraj.sengodan@hotmail.com/advanced-streaming/activityCount
# </div>

# %%
# %python

spark.sql("""
  DROP TABLE IF EXISTS stream_activity_delta
""")
spark.sql("""
  CREATE TABLE stream_activity_delta 
  USING DELTA 
  LOCATION '{}' 
""".format(activityPath))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">29</span><span class="ansired">]: </span>DataFrame[]</div>

# %%
# %sql

select * from stream_activity_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gt</th><th>count</th></tr></thead><tbody><tr><td>stairsdown</td><td>402587</td></tr><tr><td>stairsup</td><td>449685</td></tr><tr><td>stand</td><td>489536</td></tr><tr><td>bike</td><td>464277</td></tr><tr><td>null</td><td>449217</td></tr><tr><td>walk</td><td>569997</td></tr><tr><td>sit</td><td>529241</td></tr></tbody></table></div>

# %%
# %python

spark.sql("""
  DROP TABLE IF EXISTS stream_delta
""")
spark.sql("""
  CREATE TABLE stream_delta 
  USING DELTA 
  LOCATION '{}' 
""".format(basePath))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">48</span><span class="ansired">]: </span>DataFrame[]</div>

# %%
# %sql

select count(1) from stream_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>3276526</td></tr></tbody></table></div>

# %%
# %sql

select count(1) from stream_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1794269</td></tr></tbody></table></div>
